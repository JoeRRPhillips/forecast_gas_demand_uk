# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

# %%
train_data_filepath = "/mnt/c/Users/JPhillips/ldz/data/raw/train.csv"
df = pd.read_csv(train_data_filepath)

df_demand = df.pop("demand")

df = df.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df)
_ = ax.set_xticklabels(df.keys(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 8>()
#       6 df = df.melt(var_name='Column', value_name='Normalized')
#       7 plt.figure(figsize=(12, 6))
# ----> 8 ax = sns.violinplot(x='Column', y='Normalized', data=df)
#       9 _ = ax.set_xticklabels(df.keys(), rotation=90)
#
# File ~/anaconda3/envs/ml/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
train_data_filepath = "/mnt/c/Users/JPhillips/ldz/data/processed/train.csv"
df = pd.read_csv(train_data_filepath)

df_demand = df.pop("demand")
df.pop("demand_lag1")

df = df.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df)
_ = ax.set_xticklabels(df.keys(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 10>()
#       8 plt.figure(figsize=(12, 6))
#       9 ax = sns.violinplot(x='Column', y='Normalized', data=df)
# ---> 10 _ = ax.set_xticklabels(df.keys(), rotation=90)
#
# File ~/anaconda3/envs/ml/lib/python3.8/site-packages/matplotlib/axes/_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File ~/anaconda3/envs/ml/lib/python3.8/site-packages/matplotlib/axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# -> 1798 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# ...

# %%
train_data_filepath = "/mnt/c/Users/JPhillips/ldz/data/processed/train.csv"
df = pd.read_csv(train_data_filepath)

df_demand = df.pop("demand")
df.pop("demand_lag1")
df.pop("sin_yday")
df.pop("cos_yday")
df.pop("is_weekend")

df = df.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df)
_ = ax.set_xticklabels(df.keys(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 14>()
#      12 plt.figure(figsize=(12, 6))
#      13 ax = sns.violinplot(x='Column', y='Normalized', data=df)
# ---> 14 _ = ax.set_xticklabels(df.keys(), rotation=90)
#
# File ~/anaconda3/envs/ml/lib/python3.8/site-packages/matplotlib/axes/_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File ~/anaconda3/envs/ml/lib/python3.8/site-packages/matplotlib/axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# -> 1798 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# ...
